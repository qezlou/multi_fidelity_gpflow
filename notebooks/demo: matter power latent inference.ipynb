# %%
import numpy as np

from matplotlib import pyplot as plt

import gpflow

import sys
sys.path.append('../')

from mfgpflow.data_loader import PowerSpecs
from mfgpflow.linear import MultiFidelityGPModel

def generate_data(folder: str = "data/50_LR_3_HR"):
    data = PowerSpecs()
    data.read_from_txt(folder=folder)
    return data

data = generate_data("../data/50_LR_3_HR")

# %%
# visualize training spectra
for i,y_train in enumerate(data.Y_train[0]):
    if i == 0:
        plt.loglog(10**data.kf, 10**y_train, label="low-fidelity", color="C0", ls='--', alpha=0.3)
    else:
        plt.loglog(10**data.kf, 10**y_train, color="C0", ls='--', alpha=0.3)
for i,y_train in enumerate(data.Y_train[1]):
    if i == 0:
        plt.loglog(10**data.kf, 10**y_train, label="high-fidelity", color="C1")
    else:
        plt.loglog(10**data.kf, 10**y_train, color="C1")
plt.legend()
plt.xlabel(r"$k (h/\mathrm{Mpc})$")
plt.ylabel(r"$P_{k}$")
# Out:
# Text(0, 0.5, '$P_{k}$')

# %% [markdown]
# ## Latent space inference : Factor analysis using the mixing matrix

# %%
from mfgpflow.linear_svgp import LatentMFCoregionalizationSVGP

# %%
import numpy as np
import gpflow
import tensorflow as tf
from sklearn.cluster import KMeans

# 🔹 1️⃣ Load Data
X_LF, Y_LF = data.X_train_norm[0], data.Y_train_norm[0]  # LF Data (50, 5) → (50, 49)
X_HF, Y_HF = data.X_train_norm[1], data.Y_train_norm[1]  # HF Data (3, 5) → (3, 49)
X_test_HF, Y_test_HF = data.X_test_norm[0], data.Y_test[0]  # Test HF Data (10, 5) → (10, 49)

# 🔹 2️⃣ Prepare Training Data
n_LF, n_HF = X_LF.shape[0], X_HF.shape[0]  # Number of points
output_dim = Y_LF.shape[1]  # 49 output dimensions
num_latents = 10  # Reduce latent GPs to match HF sparsity
num_inducing = 50  # Reduce inducing points to prevent overfitting

# ✅ Append fidelity indicators (0 for LF, 1 for HF)
X_LF_aug = np.hstack([X_LF, np.zeros((n_LF, 1))])  # LF data with fidelity=0
X_HF_aug = np.hstack([X_HF, np.ones((n_HF, 1))])   # HF data with fidelity=1

# ✅ Combine datasets
X_train = np.vstack([X_LF_aug, X_HF_aug])  # Shape: (53, 6)
Y_train = np.vstack([Y_LF, Y_HF])  # Shape: (53, 49)

# 🔹 3️⃣ Define Multi-Fidelity GP Model
# ✅ Define base kernels for LF and HF discrepancy
kernel_L = gpflow.kernels.SquaredExponential(lengthscales=np.ones(5), variance=1.0)
kernel_delta = gpflow.kernels.SquaredExponential(lengthscales=np.ones(5), variance=1.0)

# ✅ Mixed Kernel (SE + Linear) to capture smooth & linear trends
kern_list = [gpflow.kernels.SquaredExponential() for _ in range(num_latents)]

# ✅ Optimize Inducing Points using K-Means Clustering
kmeans = KMeans(n_clusters=num_inducing, random_state=42).fit(X_train)
Z_init = kmeans.cluster_centers_

# ✅ Initialize the Latent Multi-Fidelity Coregionalization SVGP model
mf_gp = LatentMFCoregionalizationSVGP(
    X_train, Y_train,
    kernel_L, kernel_delta,
    num_outputs=output_dim, num_latents=num_latents, Z=Z_init
)

# 🔹 4️⃣ Train the Model with Adaptive Learning Rate
mf_gp.optimize(
    (X_train, Y_train),
    max_iters=2000,  # Reduce training iterations
    initial_lr=0.1,  # Lower learning rate for stability
    unfix_noise_after=500,  # Delay unfixing noise variance
    # decay_lr=True  # Enable learning rate decay
)

# 🔹 5️⃣ Make Predictions on HF Test Set
X_test_HF_aug = np.hstack([X_test_HF, np.ones((10, 1))])  # Add HF indicator (1)
mean_pred, var_pred = mf_gp.predict_f(X_test_HF_aug)

# 🔹 6️⃣ Compute Residuals
residuals = mean_pred.numpy() - Y_test_HF  # Shape: (10, 49)

# ✅ Print summary
print(f"🔍 Final Residuals: {residuals.mean():.4f} ± {residuals.std():.4f}")
print(f"✅ Model trained and predictions completed!")

# ✅ Check Learned W Matrix
print("🔍 Final Learned W Matrix:")
print(mf_gp.kernel.W.numpy())

# ✅ Check Noise Variance
print(f"🔍 Learned noise variance: {mf_gp.likelihood.variance.numpy()}")

# ✅ Evaluate Test Performance
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y_test_HF, mean_pred.numpy())
print(f"🔍 HF Prediction MSE: {mse:.4f}")

# ✅ Visualize Predictions
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
plt.plot(Y_test_HF[:, 0], label="True HF", linestyle="--", marker="o")
plt.plot(mean_pred.numpy()[:, 0], label="Predicted HF", linestyle="-", marker="x")
plt.fill_between(
    np.arange(len(Y_test_HF[:, 0])),
    mean_pred.numpy()[:, 0] - 2 * np.sqrt(var_pred.numpy()[:, 0]),
    mean_pred.numpy()[:, 0] + 2 * np.sqrt(var_pred.numpy()[:, 0]),
    alpha=0.2, color="gray", label="Confidence Interval"
)
plt.legend()
plt.title("HF Predictions vs Ground Truth")
plt.show()
# Out:
# 🔹 KMeans Inducing Points: [[0.78 0.63 0.2  0.64 0.11 0.  ]
#  [0.17 0.33 0.81 0.23 0.69 0.  ]
#  [0.25 0.61 0.57 0.93 0.81 0.  ]
#  [0.77 0.29 0.51 0.19 0.43 0.  ]
#  [0.55 0.65 0.83 0.79 0.65 0.  ]
#  [0.29 0.51 0.87 0.83 0.47 1.  ]
#  [0.79 0.17 0.35 0.85 0.63 0.  ]
#  [0.11 0.95 0.17 0.71 0.45 0.  ]
#  [0.09 0.63 0.01 0.21 0.09 0.  ]
#  [0.53 0.09 0.11 0.39 0.79 1.  ]
#  [0.21 0.89 0.65 0.03 0.25 1.  ]
#  [0.65 0.71 0.09 0.69 0.91 0.  ]
#  [0.45 0.49 0.71 0.41 0.29 0.  ]
#  [0.13 0.39 0.69 0.91 0.35 0.  ]
#  [0.71 0.55 0.91 0.53 0.37 0.  ]
#  [0.53 0.09 0.11 0.39 0.79 0.  ]
#  [0.99 0.05 0.89 0.37 0.13 0.  ]
#  [0.61 0.15 0.43 0.99 0.11 0.  ]
#  [0.03 0.21 0.55 0.07 0.23 0.  ]
#  [0.43 0.86 0.6  0.61 0.42 0.  ]
#  [0.87 0.77 0.47 0.33 0.93 0.  ]
#  [0.05 0.97 0.33 0.29 0.49 0.  ]
#  [0.31 0.93 0.37 0.89 0.77 0.  ]
#  [0.21 0.89 0.65 0.03 0.25 0.  ]
#  [0.33 0.59 0.99 0.45 0.85 0.  ]
#  [0.91 0.35 0.79 0.73 0.83 0.  ]
#  [0.89 0.47 0.03 0.95 0.03 0.  ]
#  [0.59 0.01 0.39 0.09 0.61 0.  ]
#  [0.85 0.75 0.63 0.49 0.21 0.  ]
#  [0.19 0.19 0.45 0.27 0.99 0.  ]
#  [0.37 0.13 0.95 0.51 0.67 0.  ]
#  [0.23 0.11 0.93 0.05 0.95 0.  ]
#  [0.97 0.27 0.23 0.17 0.75 0.  ]
#  [0.67 0.87 0.29 0.47 0.19 0.  ]
#  [0.53 0.74 0.3  0.79 0.65 0.  ]
#  [0.95 0.41 0.05 0.35 0.17 0.  ]
#  [0.75 0.23 0.49 0.59 0.89 0.  ]
#  [0.81 0.03 0.21 0.97 0.33 0.  ]
#  [0.39 0.43 0.07 0.25 0.05 0.  ]
#  [0.15 0.07 0.85 0.75 0.27 0.  ]
#  [0.93 0.85 0.97 0.63 0.41 0.  ]
#  [0.43 0.67 0.27 0.55 0.01 0.  ]
#  [0.07 0.57 0.67 0.15 0.87 0.  ]
#  [0.01 0.45 0.75 0.01 0.57 0.  ]
#  [0.27 0.83 0.13 0.43 0.51 0.  ]
#  [0.63 0.31 0.31 0.31 0.73 0.  ]
#  [0.41 0.37 0.73 0.13 0.39 0.  ]
#  [0.47 0.99 0.53 0.87 0.97 0.  ]
#  [0.69 0.25 0.77 0.11 0.55 0.  ]
#  [0.29 0.51 0.87 0.83 0.47 0.  ]]
# 🔹 Optimizing...
# WARNING:tensorflow:From /Users/jibanmac/Documents/conda/gpflow-env/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# 2025-02-17 22:10:14.849388: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 🔹 Iteration 0: ELBO = 3469.0100716978723
# 🔹 Iteration 10: ELBO = 1541.2345620217143
# 🔹 Iteration 20: ELBO = 294.3876406169227
# 🔹 Iteration 30: ELBO = -1001.4936619413609
# 🔹 Iteration 40: ELBO = -2214.6353818466323
# 🔹 Iteration 50: ELBO = -2858.1593328901704
# 🔹 Iteration 60: ELBO = -3267.1048946526143
# 🔹 Iteration 70: ELBO = -4891.066110805681
# 🔹 Iteration 80: ELBO = -3374.69831034367
# 🔹 Iteration 90: ELBO = -5021.386386307021
# 🔹 Iteration 100: ELBO = -5494.454043025324
# 🔹 Iteration 110: ELBO = -6396.272047919441
# 🔹 Iteration 120: ELBO = -4907.672015162526
# 🔹 Iteration 130: ELBO = -3495.1909112513817
# 🔹 Iteration 140: ELBO = -4975.382998006833
# 🔹 Iteration 150: ELBO = -5193.674325415215
# 🔹 Iteration 160: ELBO = -5686.527169841212
# 🔹 Iteration 170: ELBO = -6354.946089449862
# 🔹 Iteration 180: ELBO = -6985.0400403029535
# 🔹 Iteration 190: ELBO = -6469.863218559125
# 🔹 Iteration 200: ELBO = 2943.1344321253305
# 🔹 Iteration 210: ELBO = -2974.2052610486608
# 🔹 Iteration 220: ELBO = -4075.64112328764
# 🔹 Iteration 230: ELBO = -4266.136986957409
# 🔹 Iteration 240: ELBO = -4469.230440846753
#  [-1.40747629e-01  2.50883774e-01  2.71587055e-01  3.04732044e-01
#   -3.94810855e-06  2.60525919e-01  4.92448808e-01  3.33970016e-01
#    2.46139699e-01 -4.54357997e-05]
#  [-1.68430374e-01  2.17492988e-01  2.74201891e-01  3.00679973e-01
#    7.47869666e-07  2.40889363e-01  4.89691911e-01  3.24030349e-01
#    2.46217676e-01  3.17821669e-05]
#  [-2.26272654e-01  1.89601004e-01  2.71108205e-01  2.98884229e-01
#    3.72415560e-06  2.22588483e-01  4.84249884e-01  3.15383430e-01
#    2.46784605e-01  5.84870305e-05]
#  [-2.80458571e-01  1.68352721e-01  2.63730684e-01  2.95930062e-01
#    4.73755979e-06  1.96923624e-01  4.77159844e-01  3.13564830e-01
#    2.45448539e-01  5.31224046e-05]
#  [-3.46347856e-01  1.36545495e-01  2.65017207e-01  2.97786661e-01
#    8.43751141e-06  1.69148609e-01  4.62154373e-01  3.10274588e-01
#    2.52716460e-01  9.57798555e-05]
#  [-4.18946383e-01  1.04884011e-01  2.67643702e-01  3.02214661e-01
#    1.30649480e-05  1.39358211e-01  4.45475600e-01  3.07636822e-01
#    2.58178740e-01  1.13179766e-04]
#  [-5.07228325e-01  6.42980196e-02  2.76312294e-01  3.10994205e-01
#    1.96278366e-05  1.19813474e-01  4.26634118e-01  2.93515773e-01
#    2.66542541e-01  1.63570186e-04]]
# 🔍 Learned noise variance: 2.209686932078538e-05
# 🔍 HF Prediction MSE: 0.0003

# %%
plt.plot(mf_gp.loss_history)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.show()

# %%
# plot the W matrix
plt.imshow(mf_gp.kernel.W.numpy(), aspect="auto")
plt.colorbar()
plt.title("Learned W Matrix")
plt.ylabel("Output Dimension")
plt.xlabel("Latent Dimension")
# Out:
# Text(0.5, 0, 'Latent Dimension')

# %%
# 🔹 7️⃣ Plot Predictions vs Ground Truth
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.errorbar(np.arange(49), Y_test_HF[0], yerr=np.sqrt(var_pred.numpy()[0]), fmt='o', label="True")
plt.plot(np.arange(49), mean_pred.numpy()[0], 'r--', label="Predicted")
plt.xlabel("Output Dimension")
plt.ylabel("Prediction")
plt.legend()
plt.title("Multi-Fidelity GP Prediction (First Test Point)")
plt.show()

# 🔹 8️⃣ Residual Plot
plt.figure(figsize=(10, 5))
plt.plot(np.arange(49), residuals[0], 'bo-', label="Residuals")
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel("Output Dimension")
plt.ylabel("Residual")
plt.legend()
plt.title("Prediction Residuals (First Test Point)")
plt.show()

# %%
plt.semilogx(10**data.kf, (10**mean_pred/10**Y_test_HF).numpy().T);
plt.ylim(0.9, 1.1)
plt.xlabel(r"$k (h/\mathrm{Mpc})$")
plt.ylabel(r"$P_{k,\mathrm{pred}}/P_{k,\mathrm{true}}$")
plt.show()
# absolute error
plt.semilogx(10**data.kf, np.abs((10**mean_pred/10**Y_test_HF - 1).numpy()).mean(axis=0));
plt.xlabel(r"$k (h/\mathrm{Mpc})$")
plt.ylabel(r"$P_{k,\mathrm{pred}}-P_{k,\mathrm{true}}$")
# Out:
# Text(0, 0.5, '$P_{k,\\mathrm{pred}}-P_{k,\\mathrm{true}}$')

# %%
for var in mf_gp.trainable_variables:
    print(var.name, var.shape)
# Out:
# Variable:0 (50, 10)
# fill_triangular:0 (10, 1275)
# Variable:0 (50, 6)
# identity:0 (49, 10)
# softplus:0 (1, 1)
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (1, 1)
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (1, 1)
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (1, 1)
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (1, 1)
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (1, 1)
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (1, 1)
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (1, 1)
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (1, 1)
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (1, 1)
# softplus:0 (5,)
# softplus:0 ()
# softplus:0 (5,)
# softplus:0 ()
# chain_of_shift_of_softplus:0 ()

# %%
mf_gp
# Out:
# <mfgpflow.linear_svgp.LatentMFCoregionalizationSVGP object at 0x32190c070>
# ╒═══════════════════════════════════════════════════════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤══════════════╤═════════╤════════════════════════════════════════════╕
# │ name                                                                      │ class     │ transform        │ prior   │ trainable   │ shape        │ dtype   │ value                                      │
# ╞═══════════════════════════════════════════════════════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪══════════════╪═════════╪════════════════════════════════════════════╡
# │ LatentMFCoregionalizationSVGP.kernel.kernels[0].kernel_L.variance         │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 2e-05                                      │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[0].kernel_L.lengthscales     │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [4.66225, 3.96527, 7.00349...              │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[0].kernel_delta.variance     │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.36524                                    │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[0].kernel_delta.lengthscales │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [6.21407, 6.73792, 6.01032...              │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[0].rho                       │ Parameter │ Softplus         │         │ True        │ (1, 1)       │ float64 │ [[0.31284]]                                │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[1].kernel_L.variance         │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.0                                        │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[1].kernel_L.lengthscales     │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [4.99199, 5.73224, 6.84447...              │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[1].kernel_delta.variance     │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.7159                                     │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[1].kernel_delta.lengthscales │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [16.88034, 9.87217, 9.35954...             │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[1].rho                       │ Parameter │ Softplus         │         │ True        │ (1, 1)       │ float64 │ [[0.25118]]                                │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[2].kernel_L.variance         │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.0                                        │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[2].kernel_L.lengthscales     │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [3.78777, 5.18764, 5.14029...              │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[2].kernel_delta.variance     │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.71023                                    │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[2].kernel_delta.lengthscales │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [14.64473, 7.41208, 10.39212...            │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[2].rho                       │ Parameter │ Softplus         │         │ True        │ (1, 1)       │ float64 │ [[0.2628]]                                 │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[3].kernel_L.variance         │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.0                                        │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[3].kernel_L.lengthscales     │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [3.98537, 5.14742, 4.93736...              │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[3].kernel_delta.variance     │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.75677                                    │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[3].kernel_delta.lengthscales │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [15.53441, 7.57165, 9.83341...             │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[3].rho                       │ Parameter │ Softplus         │         │ True        │ (1, 1)       │ float64 │ [[0.46435]]                                │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[4].kernel_L.variance         │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.0                                        │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[4].kernel_L.lengthscales     │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [4.9211, 5.2753, 5.33395...                │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[4].kernel_delta.variance     │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.493                                      │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[4].kernel_delta.lengthscales │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [13.26692, 5.13898, 5.78124...             │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[4].rho                       │ Parameter │ Softplus         │         │ True        │ (1, 1)       │ float64 │ [[0.65168]]                                │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[5].kernel_L.variance         │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.03238                                    │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[5].kernel_L.lengthscales     │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [2.36733, 7.58046, 2.89644...              │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[5].kernel_delta.variance     │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.74034                                    │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[5].kernel_delta.lengthscales │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [10.1015, 9.03309, 6.53482...              │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[5].rho                       │ Parameter │ Softplus         │         │ True        │ (1, 1)       │ float64 │ [[0.5305]]                                 │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[6].kernel_L.variance         │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.04104                                    │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[6].kernel_L.lengthscales     │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [3.10904, 8.11169, 2.56164...              │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[6].kernel_delta.variance     │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.69491                                    │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[6].kernel_delta.lengthscales │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [9.90493, 6.88449, 6.36341...              │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[6].rho                       │ Parameter │ Softplus         │         │ True        │ (1, 1)       │ float64 │ [[0.68988]]                                │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[7].kernel_L.variance         │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.01163                                    │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[7].kernel_L.lengthscales     │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [5.11359, 7.03534, 2.82372...              │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[7].kernel_delta.variance     │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.72889                                    │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[7].kernel_delta.lengthscales │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [11.38159, 7.42843, 7.04219...             │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[7].rho                       │ Parameter │ Softplus         │         │ True        │ (1, 1)       │ float64 │ [[0.9552]]                                 │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[8].kernel_L.variance         │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.00045                                    │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[8].kernel_L.lengthscales     │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [6.01096, 6.39969, 4.63957...              │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[8].kernel_delta.variance     │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.69866                                    │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[8].kernel_delta.lengthscales │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [12.77572, 7.23467, 8.07652...             │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[8].rho                       │ Parameter │ Softplus         │         │ True        │ (1, 1)       │ float64 │ [[0.84123]]                                │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[9].kernel_L.variance         │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.00539                                    │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[9].kernel_L.lengthscales     │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [5.06571, 4.79656, 5.68582...              │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[9].kernel_delta.variance     │ Parameter │ Softplus         │         │ True        │ ()           │ float64 │ 0.50527                                    │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[9].kernel_delta.lengthscales │ Parameter │ Softplus         │         │ True        │ (5,)         │ float64 │ [5.12763, 3.98185, 5.47462...              │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.kernels[9].rho                       │ Parameter │ Softplus         │         │ True        │ (1, 1)       │ float64 │ [[1.36788]]                                │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.kernel.W                                    │ Parameter │ Identity         │         │ True        │ (49, 10)     │ float64 │ [[7.10730e-01, 1.04586e+00, 9.74070e-01... │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.likelihood.variance                         │ Parameter │ Softplus + Shift │         │ True        │ ()           │ float64 │ 2e-05                                      │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.inducing_variable.inducing_variable.Z       │ Parameter │ Identity         │         │ True        │ (50, 6)      │ float64 │ [[0.52753, 1.36, 0.51893...                │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.q_mu                                        │ Parameter │ Identity         │         │ True        │ (50, 10)     │ float64 │ [[1.22840e-01, 8.58600e-02, 4.87400e-02... │
# ├───────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼──────────────┼─────────┼────────────────────────────────────────────┤
# │ LatentMFCoregionalizationSVGP.q_sqrt                                      │ Parameter │ FillTriangular   │         │ True        │ (10, 50, 50) │ float64 │ [[[3.2929e-01, 0.0000e+00, 0.0000e+00...   │
# ╘═══════════════════════════════════════════════════════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧══════════════╧═════════╧════════════════════════════════════════════╛
