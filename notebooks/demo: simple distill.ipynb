# %%
import numpy as np

from matplotlib import pyplot as plt

import gpflow

# %%
# original code
#  https://github.com/EmuKit/emukit/blob/main/emukit/test_functions/forrester.py


def forrester(x, sd=0):
    """
    Forrester function
    :param x: input vector to be evaluated
    :param sd: standard deviation of noise parameter
    :return: outputs of the function
    """
    x = x.reshape((len(x), 1))
    n = x.shape[0]
    fval = ((6 * x - 2) ** 2) * np.sin(12 * x - 4)
    if sd == 0:
        noise = np.zeros(n).reshape(n, 1)
    else:
        noise = np.random.normal(0, sd, n).reshape(n, 1)
    return fval.reshape(n, 1) + noise


def forrester_low(x, sd=0):
    """
    Low fidelity forrester function approximation:

    f(x) = 0.5 * forrester(x) + 10 * (x - 0.5) + 5 + N(0, sd)

    so

    forrester(x) = 2 * f(x) - 10 * (x - 0.5) - 5

    :param x: input vector to be evaluated
    :param sd: standard deviation of observation noise at low fidelity
    :return: outputs of the function
    """
    high_fidelity = forrester(x, 0)
    return (
        0.5 * high_fidelity
        + 10 * (x[:, [0]] - 0.5)
        + 5
        + np.random.randn(x.shape[0], 1) * sd
    )

# %%
import numpy as np

np.random.seed(42)

# Define high-fidelity and low-fidelity functions
high_fidelity = forrester
low_fidelity = forrester_low

# Generate plot inputs
x_plot = np.linspace(0, 1, 200)[:, None]

# Correct fidelity indicators (ensuring integer dtype)
X_L_plot = np.hstack([x_plot, np.zeros_like(x_plot, dtype=int)])  # LF test points
X_H_plot = np.hstack([x_plot, np.ones_like(x_plot, dtype=int)])   # HF test points

# Generate true function values for comparison
y_plot_l = low_fidelity(x_plot)
y_plot_h = high_fidelity(x_plot)

# Generate training data
x_train_l = np.atleast_2d(np.random.rand(40)).T
x_train_h = np.atleast_2d(np.random.permutation(x_train_l)[:13])

y_train_l = low_fidelity(x_train_l)
y_train_h = high_fidelity(x_train_h)

# Append integer fidelity indicators
X_L = np.hstack([x_train_l, np.zeros_like(x_train_l, dtype=int)])  # LF training
X_H = np.hstack([x_train_h, np.ones_like(x_train_h, dtype=int)])   # HF training

# Merge datasets
X = np.vstack([X_L, X_H])
Y = np.vstack([y_train_l, y_train_h])

# Debug: Print dataset info
print("\n🔍 Dataset Info:")
print(f"  X_L shape: {X_L.shape}, X_H shape: {X_H.shape}")
print(f"  X shape: {X.shape}, Y shape: {Y.shape}")
print(f"  X_L_plot shape: {X_L_plot.shape}, X_H_plot shape: {X_H_plot.shape}")
print(f"  First few X_L entries:\n{X_L[:5]}")
print(f"  First few X_H entries:\n{X_H[:5]}")
# Out:
# 🔍 Dataset Info:
#   X_L shape: (40, 2), X_H shape: (13, 2)
#   X shape: (53, 2), Y shape: (53, 1)
#   X_L_plot shape: (200, 2), X_H_plot shape: (200, 2)
#   First few X_L entries:
# [[0.87737307 0.        ]
#  [0.74076862 0.        ]
#  [0.69701574 0.        ]
#  [0.70248408 0.        ]
#  [0.35949115 0.        ]]
#   First few X_H entries:
# [[0.70248408 1.        ]
#  [0.21582103 1.        ]
#  [0.03050025 1.        ]
#  [0.03594227 1.        ]
#  [0.09398194 1.        ]]

# %%
X.shape, Y.shape
# Out:
# ((53, 2), (53, 1))

# %%
# plot the data
plt.figure(figsize=(12, 6))
plt.plot(x_plot, y_plot_l, "k--", label="Low fidelity")
plt.plot(x_plot, y_plot_h, "k", label="High fidelity")
plt.plot(x_train_l, y_train_l, "bo", label="Low fidelity observations")
plt.plot(x_train_h, y_train_h, "ro", label="High fidelity observations")
plt.legend()
plt.show()

# %% [markdown]
# ## AR1 Model in GPFlow

# %%
# include the import path from previous directory
import sys
sys.path.append("..")

# %%
from mfgpflow.linear import MultiFidelityGPModel

# Define kernels
kernel_L = gpflow.kernels.SquaredExponential()
kernel_delta = gpflow.kernels.SquaredExponential()

# %%
# Train multi-fidelity GP
mf_gp = MultiFidelityGPModel(X, Y, kernel_L, kernel_delta)

# First pass: Optimize with noise fixed, then unfix after 500 steps
mf_gp.optimize(max_iters=1000, learning_rate=0.01, use_adam=False, unfix_noise_after=500)

# Print final learned noise variance
print("Learned noise variance:", mf_gp.likelihood.variance.numpy())
# Out:
# Optimizing with L-BFGS (Scipy)...
# 2025-03-06 11:16:07.829725: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Learned noise variance: 1e-06

# %%
print("Final learned rho values:", mf_gp.kernel.rho.numpy())
# Out:
# Final learned rho values: [[1.99976989]]

# %%
import numpy as np
import matplotlib.pyplot as plt

# 🔹 1️⃣ Ensure Fidelity Indicators Are Correct
def check_fidelity_values(X, name):
    """ Prints unique fidelity values to confirm proper dataset formatting. """
    print(f"\n🔍 Checking Fidelity Values in {name}:")
    print(f"  Unique values in {name}[:, -1]: {np.unique(X[:, -1])}")
    print(f"  Shape: {X.shape}")
    print(f"  First few entries:\n{X[:5]}")

# 🔹 2️⃣ Ensure Model Can Evaluate Covariance
def check_kernel_evaluation():
    """ Checks if the kernel can compute covariance correctly. """
    try:
        print("Testing K(X_L_plot, X) shape:", mf_gp.kernel.K(np.vstack([X_L_plot, X_H]), X).shape)
        print("Testing K(X_H_plot, X) shape:", mf_gp.kernel.K(np.vstack([X_H_plot, X_H]), X).shape)
    except Exception as e:
        print("❌ Kernel evaluation failed:", e)

# ✅ Ensure Fidelity Indicators Are Properly Set
check_fidelity_values(X, "Training Set (X)")
check_fidelity_values(X_L_plot, "X_L_plot (Low-Fidelity Test)")
check_fidelity_values(X_H_plot, "X_H_plot (High-Fidelity Test)")

# ✅ Ensure Model Can Evaluate Kernel
check_kernel_evaluation()

# 🔹 3️⃣ Predict at New Test Points (Including HF Training Points)
print("\n🔍 Running GP Predictions...")
mean_LF, var_LF = mf_gp.predict_f(np.vstack([X_L_plot, X_H]))  # Ensure HF points are included
mean_HF, var_HF = mf_gp.predict_f(np.vstack([X_H_plot, X_H]))  # Ensure HF points are included

# ✅ Debug Prediction Outputs
print("\n🔍 Prediction Debug Info:")
print(f"  mean_LF shape: {mean_LF.shape}, var_LF shape: {var_LF.shape}")
print(f"  mean_HF shape: {mean_HF.shape}, var_HF shape: {var_HF.shape}")

# 🔹 4️⃣ Plot Multi-Fidelity GP Predictions
plt.figure(figsize=(10, 6))

# Plot True Functions
plt.plot(x_plot, y_plot_l, 'b--', label="True LF Function")
plt.plot(x_plot, y_plot_h, 'r--', label="True HF Function")

# Plot GP Predictions
plt.plot(x_plot, mean_LF[:200], 'b-', label="Predicted LF Mean")  # First 200 are LF test points
plt.fill_between(
    x_plot.flatten(), 
    (mean_LF[:200] - 2 * np.sqrt(var_LF[:200])).numpy().flatten(), 
    (mean_LF[:200] + 2 * np.sqrt(var_LF[:200])).numpy().flatten(), 
    color='b', alpha=0.2, label="LF 2σ Uncertainty"
)
plt.plot(x_plot, mean_HF[:200], 'r-', label="Predicted HF Mean")  # First 200 are HF test points
plt.fill_between(
    x_plot.flatten(), 
    (mean_HF[:200] - 2 * np.sqrt(var_HF[:200])).numpy().flatten(), 
    (mean_HF[:200] + 2 * np.sqrt(var_HF[:200])).numpy().flatten(), 
    color='r', alpha=0.2, label="HF 2σ Uncertainty"
)

# Overlay Training Data
plt.scatter(X[:, 0][X[:, -1] == 0], Y[X[:, -1] == 0], color='b', marker='x', label="LF Training Data")
plt.scatter(X[:, 0][X[:, -1] == 1], Y[X[:, -1] == 1], color='r', marker='o', label="HF Training Data")

plt.xlabel("X")
plt.ylabel("Function Value")
plt.legend()
plt.title("Multi-Fidelity GP Predictions on Forrester Function")
plt.show()
# Out:
# 🔍 Checking Fidelity Values in Training Set (X):
#   Unique values in Training Set (X)[:, -1]: [0. 1.]
#   Shape: (53, 2)
#   First few entries:
# [[0.87737307 0.        ]
#  [0.74076862 0.        ]
#  [0.69701574 0.        ]
#  [0.70248408 0.        ]
#  [0.35949115 0.        ]]
#
# 🔍 Checking Fidelity Values in X_L_plot (Low-Fidelity Test):
#   Unique values in X_L_plot (Low-Fidelity Test)[:, -1]: [0.]
#   Shape: (200, 2)
#   First few entries:
# [[0.         0.        ]
#  [0.00502513 0.        ]
#  [0.01005025 0.        ]
#  [0.01507538 0.        ]
#  [0.0201005  0.        ]]
#
# 🔍 Checking Fidelity Values in X_H_plot (High-Fidelity Test):
#   Unique values in X_H_plot (High-Fidelity Test)[:, -1]: [1.]
#   Shape: (200, 2)
#   First few entries:
# [[0.         1.        ]
#  [0.00502513 1.        ]
#  [0.01005025 1.        ]
#  [0.01507538 1.        ]
#  [0.0201005  1.        ]]
# Testing K(X_L_plot, X) shape: (213, 53)
# Testing K(X_H_plot, X) shape: (213, 53)
#
# 🔍 Running GP Predictions...
#
# 🔍 Prediction Debug Info:
#   mean_LF shape: (213, 1), var_LF shape: (213, 1)
#   mean_HF shape: (213, 1), var_HF shape: (213, 1)

# %%
mean_LF, var_LF = mf_gp.predict_f(X_L_plot)  # Ensure HF points are included

# %% [markdown]
# ## Distillation MF GP

# %%
from mfgpflow.distillation import MFGPDistiller

distiller = MFGPDistiller(niterations=100)
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
mean_LF, var_LF = mf_gp.predict_f(X_L_plot)  # Ensure HF points are included
mean_HF, var_HF = mf_gp.predict_f(X_H_plot)  # Ensure HF points are included

train_data = distiller.generate_training_data(
    mean_HF.numpy()[:, 0], np.sqrt(var_HF.numpy()[:, 0]), mean_LF.numpy()[:, 0], X_L_plot[:, 0], sample_size=100,
)

# %%
train_data
# Out:
#         mu_LF         x     mu_HF  sigma_HF
# 0    1.694457  0.201005 -0.630263  0.001078
# 1    4.841952  0.688442 -4.085636  0.000568
# 2    4.495618  0.723618 -5.481627  0.000869
# 3   13.024690  0.914573  7.757896  0.001004
# 4    3.842459  0.381910  0.047145  0.001273
# ..        ...       ...       ...       ...
# 95   4.628238  0.442211  0.412242  0.001650
# 96   5.870865  0.608040 -0.420005  0.001049
# 97   5.986616  0.562814  0.716113  0.001119
# 98   6.094230  0.814070 -4.093097  0.000828
# 99   0.783205  0.060302  0.359972  0.001244
#
# [100 rows x 4 columns]

# %%
distiller.train(train_data)
# Out:
# /Users/jibanmac/Documents/conda/gpflow-env/lib/python3.9/site-packages/pysr/sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /Users/jibanmac/Documents/conda/gpflow-env/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/jibanmac/Documents/conda/gpflow-env/lib/python3.9/site-packages/pysr/sr.py:73: UserWarning: You are using the `^` operator, but have not set up `constraints` for it. This may lead to overly complex expressions. One typical constraint is to use `constraints={..., '^': (-1, 1)}`, which will allow arbitrary-complexity base (-1) but only powers such as a constant or variable (1). For more tips, please see https://astroautomata.com/PySR/tuning/
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 3.950e+05
# Head worker occupation: 21.7%
# Progress: 949 / 10000 total iterations (9.490%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.786e+06  1.594e+01  y = -1.1092
# 3           8.158e+06  3.709e-02  y = x * -2.3874
# 5           2.040e+06  6.931e-01  y = (x * -11.194) + mu_LF
# 7           3.106e-01  7.560e+00  y = mu_LF - ((x * 20) - mu_LF)
# 9           2.940e-01  2.745e-02  y = ((x * -20.001) + mu_LF) - (-0.00024188 - mu_LF)
# 11          2.850e-01  1.552e-02  y = ((x * -20.001) + ((mu_LF * 1.0001) - -0.00023381)) + mu_LF
# 13          2.026e-01  1.707e-01  y = (((x * -20.002) + (mu_LF + (-6.3569e-05 / x))) + mu_LF) - ...
#                                   -0.0010546
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.290e+05
# Head worker occupation: 21.3%
# Progress: 2078 / 10000 total iterations (20.780%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.786e+06  1.594e+01  y = -1.1092
# 3           8.158e+06  3.709e-02  y = x * -2.3874
# 5           2.040e+06  6.931e-01  y = (x * -11.194) + mu_LF
# 7           3.106e-01  7.560e+00  y = mu_LF - ((x * 20) - mu_LF)
# 9           2.940e-01  2.745e-02  y = ((x * -20.001) + mu_LF) - (-0.00024188 - mu_LF)
# 11          2.850e-01  1.552e-02  y = ((x * -20.001) + ((mu_LF * 1.0001) - -0.00023381)) + mu_LF
# 13          2.026e-01  1.707e-01  y = (((x * -20.002) + (mu_LF + (-6.3569e-05 / x))) + mu_LF) - ...
#                                   -0.0010546
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.430e+05
# Head worker occupation: 21.2%
# Progress: 3231 / 10000 total iterations (32.310%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.786e+06  1.594e+01  y = -1.1092
# 3           8.158e+06  3.709e-02  y = x * -2.3874
# 5           2.040e+06  6.931e-01  y = (x * -11.194) + mu_LF
# 7           3.106e-01  7.560e+00  y = mu_LF - ((x * 20) - mu_LF)
# 9           2.940e-01  2.745e-02  y = ((x * -20.001) + mu_LF) - (-0.00024188 - mu_LF)
# 11          2.850e-01  1.552e-02  y = ((x * -20.001) + ((mu_LF * 1.0001) - -0.00023381)) + mu_LF
# 13          2.026e-01  1.707e-01  y = (((x * -20.002) + (mu_LF + (-6.3569e-05 / x))) + mu_LF) - ...
#                                   -0.0010546
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.330e+05
# Head worker occupation: 22.1%
# Progress: 4110 / 10000 total iterations (41.100%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.786e+06  1.594e+01  y = -1.1092
# 3           8.158e+06  3.709e-02  y = x * -2.3874
# 5           2.040e+06  6.931e-01  y = (x * -11.194) + mu_LF
# 7           3.106e-01  7.560e+00  y = mu_LF - ((x * 20) - mu_LF)
# 9           2.940e-01  2.745e-02  y = ((x * -20.001) + mu_LF) - (-0.00024188 - mu_LF)
# 11          2.850e-01  1.552e-02  y = ((x * -20.001) + ((mu_LF * 1.0001) - -0.00023381)) + mu_LF
# 13          2.026e-01  1.707e-01  y = (((x * -20.002) + (mu_LF + (-6.3569e-05 / x))) + mu_LF) - ...
#                                   -0.0010546
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.130e+05
# Head worker occupation: 21.2%
# Progress: 4875 / 10000 total iterations (48.750%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.786e+06  1.594e+01  y = -1.1092
# 3           8.158e+06  3.709e-02  y = x * -2.3874
# 5           2.040e+06  6.931e-01  y = (x * -11.194) + mu_LF
# 7           3.106e-01  7.560e+00  y = mu_LF - ((x * 20) - mu_LF)
# 9           2.940e-01  2.745e-02  y = ((x * -20.001) + mu_LF) - (-0.00024188 - mu_LF)
# 11          2.850e-01  1.552e-02  y = ((x * -20.001) + ((mu_LF * 1.0001) - -0.00023381)) + mu_LF
# 13          2.026e-01  1.707e-01  y = (((x * -20.002) + (mu_LF + (-6.3569e-05 / x))) + mu_LF) - ...
#                                   -0.0010546
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.850e+05
# Head worker occupation: 21.5%
# Progress: 5665 / 10000 total iterations (56.650%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.786e+06  1.594e+01  y = -1.1092
# 3           8.158e+06  3.709e-02  y = x * -2.3874
# 5           2.040e+06  6.931e-01  y = (x * -11.194) + mu_LF
# 7           3.106e-01  7.560e+00  y = mu_LF - ((x * 20) - mu_LF)
# 9           2.940e-01  2.745e-02  y = ((x * -20.001) + mu_LF) - (-0.00024188 - mu_LF)
# 11          2.850e-01  1.552e-02  y = ((x * -20.001) + ((mu_LF * 1.0001) - -0.00023381)) + mu_LF
# 13          2.026e-01  1.707e-01  y = (((x * -20.002) + (mu_LF + (-6.3569e-05 / x))) + mu_LF) - ...
#                                   -0.0010546
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.550e+05
# Head worker occupation: 21.1%
# Progress: 6490 / 10000 total iterations (64.900%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.786e+06  1.594e+01  y = -1.1092
# 3           8.158e+06  3.709e-02  y = x * -2.3874
# 5           2.040e+06  6.931e-01  y = (x * -11.194) + mu_LF
# 7           3.106e-01  7.560e+00  y = mu_LF - ((x * 20) - mu_LF)
# 9           2.940e-01  2.745e-02  y = ((x * -20.001) + mu_LF) - (-0.00024188 - mu_LF)
# 11          2.850e-01  1.552e-02  y = ((x * -20.001) + ((mu_LF * 1.0001) - -0.00023381)) + mu_LF
# 13          2.026e-01  1.707e-01  y = (((x * -20.002) + (mu_LF + (-6.3569e-05 / x))) + mu_LF) - ...
#                                   -0.0010546
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.400e+05
# Head worker occupation: 20.4%
# Progress: 7308 / 10000 total iterations (73.080%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.786e+06  1.594e+01  y = -1.1092
# 3           8.158e+06  3.709e-02  y = x * -2.3874
# 5           2.040e+06  6.931e-01  y = (x * -11.194) + mu_LF
# 7           3.106e-01  7.560e+00  y = mu_LF - ((x * 20) - mu_LF)
# 9           2.940e-01  2.745e-02  y = ((x * -20.001) + mu_LF) - (-0.00024188 - mu_LF)
# 11          2.850e-01  1.552e-02  y = ((x * -20.001) + ((mu_LF * 1.0001) - -0.00023381)) + mu_LF
# 13          2.026e-01  1.707e-01  y = (((x * -20.002) + (mu_LF + (-6.3569e-05 / x))) + mu_LF) - ...
#                                   -0.0010546
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.450e+05
# Head worker occupation: 20.0%
# Progress: 8138 / 10000 total iterations (81.380%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.786e+06  1.594e+01  y = -1.1092
# 3           8.158e+06  3.709e-02  y = x * -2.3874
# 5           2.040e+06  6.931e-01  y = (x * -11.194) + mu_LF
# 7           3.106e-01  7.560e+00  y = mu_LF - ((x * 20) - mu_LF)
# 9           2.940e-01  2.745e-02  y = ((x * -20.001) + mu_LF) - (-0.00024188 - mu_LF)
# 11          2.850e-01  1.552e-02  y = ((x * -20.001) + ((mu_LF * 1.0001) - -0.00023381)) + mu_LF
# 13          2.026e-01  1.707e-01  y = (((x * -20.002) + (mu_LF + (-6.3569e-05 / x))) + mu_LF) - ...
#                                   -0.0010546
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.490e+05
# Head worker occupation: 20.1%
# Progress: 8967 / 10000 total iterations (89.670%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.786e+06  1.594e+01  y = -1.1092
# 3           8.158e+06  3.709e-02  y = x * -2.3874
# 5           2.040e+06  6.931e-01  y = (x * -11.194) + mu_LF
# 7           3.106e-01  7.560e+00  y = mu_LF - ((x * 20) - mu_LF)
# 9           2.940e-01  2.745e-02  y = ((x * -20.001) + mu_LF) - (-0.00024188 - mu_LF)
# 11          2.850e-01  1.552e-02  y = ((x * -20.001) + ((mu_LF * 1.0001) - -0.00023381)) + mu_LF
# 13          2.026e-01  1.707e-01  y = (((x * -20.002) + (mu_LF + (-6.3569e-05 / x))) + mu_LF) - ...
#                                   -0.0010546
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.460e+05
# Head worker occupation: 20.2%
# Progress: 9785 / 10000 total iterations (97.850%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.786e+06  1.594e+01  y = -1.1092
# 3           8.158e+06  3.709e-02  y = x * -2.3874
# 5           2.040e+06  6.931e-01  y = (x * -11.194) + mu_LF
# 7           3.106e-01  7.560e+00  y = mu_LF - ((x * 20) - mu_LF)
# 9           2.940e-01  2.745e-02  y = ((x * -20.001) + mu_LF) - (-0.00024188 - mu_LF)
# 11          2.850e-01  1.552e-02  y = ((x * -20.001) + ((mu_LF * 1.0001) - -0.00023381)) + mu_LF
# 13          2.026e-01  1.707e-01  y = (((x * -20.002) + (mu_LF + (-6.3569e-05 / x))) + mu_LF) - ...
#                                   -0.0010546
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.

# %%
equation = distiller.get_equation()
print("Discovered Equation:", equation)
# Out:
# Discovered Equation: complexity                                                      13
# loss                                                      0.202608
# score                                                      0.17067
# equation         (((x * -20.001911) + (mu_LF + (-6.356929e-5 / ...
# sympy_format     mu_LF + mu_LF + x*(-20.001911) - 1*(-0.0010546...
# lambda_format    PySRFunction(X=>mu_LF + mu_LF + x*(-20.001911)...
# Name: 6, dtype: object

# %%
distiller.model.sympy()
# Out:
# mu_LF + mu_LF + x*(-20.001911) - 1*(-0.001054616) - 6.356929e-5/x

# %%
y_pred_distill = distiller.predict(mu_LF=mean_LF.numpy()[:, 0], x=X_L_plot[:, 0])
# Out:
# /Users/jibanmac/Documents/conda/gpflow-env/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# <lambdifygenerated-1>:2: RuntimeWarning: divide by zero encountered in divide
#   return mu_LF + mu_LF + (-20.001911)*x - (-0.001054616) - 6.356929e-5/x

# %%
import numpy as np
import matplotlib.pyplot as plt

# 🔹 3️⃣ Predict at New Test Points (Including HF Training Points)
print("\n🔍 Running GP Predictions...")
mean_LF, var_LF = mf_gp.predict_f(np.vstack([X_L_plot, X_H]))  # Ensure HF points are included
mean_HF, var_HF = mf_gp.predict_f(np.vstack([X_H_plot, X_H]))  # Ensure HF points are included

# ✅ Debug Prediction Outputs
print("\n🔍 Prediction Debug Info:")
print(f"  mean_LF shape: {mean_LF.shape}, var_LF shape: {var_LF.shape}")
print(f"  mean_HF shape: {mean_HF.shape}, var_HF shape: {var_HF.shape}")

# 🔹 4️⃣ Plot Multi-Fidelity GP Predictions
plt.figure(figsize=(10, 6))

# Plot True Functions
plt.plot(x_plot, y_plot_l, 'b--', label="True LF Function")
plt.plot(x_plot, y_plot_h, 'r--', label="True HF Function")

# Plot GP Predictions
plt.plot(x_plot, mean_LF[:200], 'b-', label="Predicted LF Mean")  # First 200 are LF test points
plt.fill_between(
    x_plot.flatten(), 
    (mean_LF[:200] - 2 * np.sqrt(var_LF[:200])).numpy().flatten(), 
    (mean_LF[:200] + 2 * np.sqrt(var_LF[:200])).numpy().flatten(), 
    color='b', alpha=0.2, label="LF 2σ Uncertainty"
)
plt.plot(x_plot, mean_HF[:200], 'r-', label="Predicted HF Mean")  # First 200 are HF test points
plt.fill_between(
    x_plot.flatten(), 
    (mean_HF[:200] - 2 * np.sqrt(var_HF[:200])).numpy().flatten(), 
    (mean_HF[:200] + 2 * np.sqrt(var_HF[:200])).numpy().flatten(), 
    color='r', alpha=0.2, label="HF 2σ Uncertainty"
)

# Overlay Training Data
plt.scatter(X[:, 0][X[:, -1] == 0], Y[X[:, -1] == 0], color='b', marker='x', label="LF Training Data")
plt.scatter(X[:, 0][X[:, -1] == 1], Y[X[:, -1] == 1], color='r', marker='o', label="HF Training Data")

# Plot Distilled Predictions
plt.plot(X_L_plot[:, 0], y_pred_distill, 'g-', label="Distilled Mean")

plt.xlabel("X")
plt.ylabel("Function Value")
plt.legend()
plt.title("Multi-Fidelity GP Predictions on Forrester Function")
plt.show()
# Out:
# 🔍 Running GP Predictions...
#
# 🔍 Prediction Debug Info:
#   mean_LF shape: (213, 1), var_LF shape: (213, 1)
#   mean_HF shape: (213, 1), var_HF shape: (213, 1)
